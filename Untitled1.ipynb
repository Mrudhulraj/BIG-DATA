# %%
import numpy as np
import pandas as pd

# %%
df_a_01=pd.read_csv("SGD_a0.01_log.csv")
df_a_1=pd.read_csv("SGD_a0.1_log.csv")
df_a_0001=pd.read_csv("SGD_a0.0001_log.csv")

# %%
max_f1_df2 = max(df_a_01["max_f1score"])
max_f1_df3 = max(df_a_1["max_f1score"])
max_f1_df1 = max(df_a_0001["max_f1score"])
# Out:
# 0.6060606060606061

# %%
import matplotlib.pyplot as plt
plt.xlabel("Alpha") 
plt.ylabel("Maximum F1 Score") 

plt.plot(np.array([0.0001,0.01,0.1]),np.array([max_f1_df1, max_f1_df2,max_f1_df3]))

# %%
pac_1000_df = pd.read_csv("PAC_1000.csv")
SGD_hinge_1000_df = pd.read_csv("SGD_1000_hinge.csv")
SGD_log_3000_df=pd.read_csv("SGD_3000_log.csv")
MNB_300_df = pd.read_csv("MNB_300.csv")

# %%
max_f1_df1 = max(pac_1000_df["max_f1score"])
max_f1_df2 = max(SGD_hinge_1000_df["max_f1score"])
max_f1_df3 = max(SGD_log_3000_df["max_f1score"])
max_f1_df4 = max(MNB_300_df["max_f1score"])
print("PAC 1000:",max_f1_df1)
print("SGD 1000 hinge:",max_f1_df2)
print("SGD 3000 log:",max_f1_df3)
print("MNB 300:",max_f1_df4)
# Out:
# PAC 1000: 0.7258883248730965
# SGD 1000 hinge: 0.6631853785900783
# SGD 3000 log: 0.6435070306038049
# MNB 300: 0.727273

# %%
max_f1_df1 = max(pac_1000_df["max_f1score"])
max_f1_df2 = max(pac_2000_df["max_f1score"])

# %%
plt.xlabel("Batch Size") 
plt.ylabel("Maximum F1 Score") 

plt.plot(np.array([1000, 2000,6000]),np.array([max_f1_df1, max_f1_df2,0.65]))
